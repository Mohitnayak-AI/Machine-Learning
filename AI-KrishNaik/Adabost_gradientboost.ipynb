# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./Random Forest/Travel.csv')
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
# 2          Basic                    3.0        Single            7.0
# 3          Basic                    3.0      Divorced            2.0
# 4          Basic                    4.0      Divorced            1.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
# 2         1                       3       0                       0.0
# 3         1                       5       1                       1.0
# 4         0                       5       1                       0.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0
# 2   Executive        17090.0
# 3   Executive        17909.0
# 4   Executive        18468.0

# %% [markdown]
# ## Data Cleaning
#     1. Handel Missing Values
#     2. Handel Duplicate
#     3. Check data type
#     4. understand the dataset

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
# Check all categorical features

df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].replace('Fe Male','Female')
df['MaritalStatus'] = df['MaritalStatus'].replace('Single','Unmarried')

# %%
## Check Missing Values
feature_with_na = [feature for feature in df.columns if df[feature].isnull().sum()>=1]
for feature in feature_with_na:
    print(feature,np.round(df[feature].isnull().mean()*100,5),'% missing values')
# Out:
# Age 4.62357 % missing values
# TypeofContact 0.51146 % missing values
# DurationOfPitch 5.13502 % missing values
# NumberOfFollowups 0.92062 % missing values
# PreferredPropertyStar 0.53191 % missing values
# NumberOfTrips 2.86416 % missing values
# NumberOfChildrenVisiting 1.35025 % missing values
# MonthlyIncome 4.76678 % missing values

# %%
# Statistics on numerical col(null col)

df[feature_with_na].select_dtypes(exclude='object').describe()
# Out:
#                Age  DurationOfPitch  NumberOfFollowups  PreferredPropertyStar  \
# count  4662.000000      4637.000000        4843.000000            4862.000000
# mean     37.622265        15.490835           3.708445               3.581037
# std       9.316387         8.519643           1.002509               0.798009
# min      18.000000         5.000000           1.000000               3.000000
# 25%      31.000000         9.000000           3.000000               3.000000
# 50%      36.000000        13.000000           4.000000               3.000000
# 75%      44.000000        20.000000           4.000000               4.000000
# max      61.000000       127.000000           6.000000               5.000000
#
#        NumberOfTrips  NumberOfChildrenVisiting  MonthlyIncome
# count    4748.000000               4822.000000    4655.000000
# mean        3.236521                  1.187267   23619.853491
# std         1.849019                  0.857861    5380.698361
# min         1.000000                  0.000000    1000.000000
# 25%         2.000000                  1.000000   20346.000000
# 50%         3.000000                  1.000000   22347.000000
# 75%         4.000000                  2.000000   25571.000000
# max        22.000000                  3.000000   98678.000000

# %% [markdown]
# ## Imputing Null Values
#     1. Median for Age
#     2. Mode for Type of contract
#     3. Median for Duration of Pitch
#     4. Mode for Number of Follow up as it is Discrete Feature
#     5. Mode for Preferred Property Star
#     6. Median for Number of Tips
#     7. Mode for Number of Children Visiting
#     8. Median for Monthly Income

# %%
# age
df['Age'].fillna(df['Age'].median(),inplace=True)

# Typeofcontract
df['TypeofContact'].fillna(df.TypeofContact.mode()[0],inplace=True)

#Durationofpitch
df['DurationOfPitch'].fillna(df.DurationOfPitch.median(),inplace=True)

#Numberoffollowup
df['NumberOfFollowups'].fillna(df.NumberOfFollowups.mode()[0],inplace=True)

#preferredpropertystar
df['PreferredPropertyStar'].fillna(df.PreferredPropertyStar.mode()[0],inplace=True)

#numberoftips
df['NumberOfTrips'].fillna(df.NumberOfTrips.median(),inplace=True)

#numberofchildrenvisiting
df['NumberOfChildrenVisiting'].fillna(df.NumberOfChildrenVisiting.mode()[0],inplace=True)

#monthlyincome
df['MonthlyIncome'].fillna(df.MonthlyIncome.median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
# customer id is not importent

df.drop('CustomerID',axis=1,inplace=True)
df.head()
# Out:
#    ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0          1  41.0     Self Enquiry         3              6.0
# 1          0  49.0  Company Invited         1             14.0
# 2          1  37.0     Self Enquiry         1              8.0
# 3          0  33.0  Company Invited         1              9.0
# 4          0  36.0     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0     Unmarried            1.0
# 1         Deluxe                    4.0      Divorced            2.0
# 2          Basic                    3.0     Unmarried            7.0
# 3          Basic                    3.0      Divorced            2.0
# 4          Basic                    4.0      Divorced            1.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
# 2         1                       3       0                       0.0
# 3         1                       5       1                       1.0
# 4         0                       5       1                       0.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0
# 2   Executive        17090.0
# 3   Executive        17909.0
# 4   Executive        18468.0

# %% [markdown]
# ## Feaure Engineering

# %%
df['TotalVisiting'] = df['NumberOfPersonVisiting'] + df['NumberOfChildrenVisiting']
df.drop(columns=['NumberOfPersonVisiting','NumberOfChildrenVisiting'],axis=1,inplace=True)
df.shape
# Out:
# (4888, 18)

# %%
# Get all the numrical feature

num_feature = [feature for feature in df.columns if df[feature].dtype != 'O' ]

# for feature in num_feature:
#     print(feature)

print('length is :' ,len(num_feature))
# Out:
# length is : 12

# %%
# get all the cate feature

cate_feature = [feature for feature in df.columns if df[feature].dtype == 'O']

# for featrue in cate_feature:
#     print(feature)
    
print('length is: ',len(cate_feature))
# Out:
# length is:  6

# %%
# Discrete feature
discreate_feature = [feature for feature in num_feature if len(df[feature].unique())<25]

# for feature in discreate_feature:
#     print(featrue)
    
print('length is: ',len(discreate_feature))
# Out:
# length is:  9

# %%
# coontinuous feature
continuous_feature = [feature for feature in num_feature if feature not in discreate_feature]

# for feature in continuous_feature:
#     print(featrue)
    
print('lenght is: ', len(continuous_feature))
# Out:
# lenght is:  3

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split

x = df.drop('ProdTaken',axis=1)
y = df['ProdTaken']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y.value_counts()
# Out:
# ProdTaken
# 0    3968
# 1     920
# Name: count, dtype: int64

# %%
cat_feature = x.select_dtypes(include='object').columns
num_feature = x.select_dtypes(exclude='object').columns

from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

scale = StandardScaler()
encode = OneHotEncoder(drop='first')

preprocessing = ColumnTransformer(
    [
        ("OneHotEncoder",encode,cat_feature),
        ("StandardScaler",scale,num_feature)
    ]
)

# %%
preprocessing
# Out:
# ColumnTransformer(transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  Index(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
#        'MaritalStatus', 'Designation'],
#       dtype='object')),
#                                 ('StandardScaler', StandardScaler(),
#                                  Index(['Age', 'CityTier', 'DurationOfPitch', 'NumberOfFollowups',
#        'PreferredPropertyStar', 'NumberOfTrips', 'Passport',
#        'PitchSatisfactionScore', 'OwnCar', 'MonthlyIncome', 'TotalVisiting'],
#       dtype='object'))])

# %%
# Appling tranfermation in traing dataset(fit_transform)
x_train = preprocessing.fit_transform(x_train)

# appling transformation in test dataset(transform)
x_test = preprocessing.transform(x_test)

# %%
# RF Traning
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,precision_score,recall_score,f1_score,roc_curve,roc_auc_score,ConfusionMatrixDisplay

# %%
models = {
    
    "Desision Tree" : DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    "AdaBoost":AdaBoostClassifier(),
    "GradientBoost":GradientBoostingClassifier()
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train,y_train) # Train Model
    
    # make Predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    # Training set Performanest
    model_train_accuracy = accuracy_score(y_train,y_train_pred)
    model_train_fi = f1_score(y_train,y_train_pred,average='weighted')
    model_train_precision = precision_score(y_train,y_train_pred)
    model_train_recall = recall_score(y_train,y_train_pred)
    model_train_roc_auc_score = roc_auc_score(y_train,y_train_pred)
    
    # Test set Performance
    model_test_accuracy = accuracy_score(y_test,y_test_pred)
    model_test_fi = f1_score(y_test,y_test_pred,average='weighted')
    model_test_precision = precision_score(y_test,y_test_pred)
    model_test_recall = recall_score(y_test,y_test_pred)
    model_test_roc_auc_score = roc_auc_score(y_test,y_test_pred)
    
    print(list(models.keys())[i])
    
    print('Model Performanse for Training')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print("- F1 Score: {:.4f}".format(model_train_fi))
    print("- Precision: {:.4f}".format(model_train_precision))
    print("- Recall: {:.4f}".format(model_train_recall))
    print("- Roc Auc Score: {:.4f}".format(model_train_roc_auc_score))
    
    print('-------------------------------------------')
    
    print('Model Performanse for Test')
    print("- Accuracy: {:.4f}".format(model_test_accuracy))
    print("- F1 Score: {:.4f}".format(model_test_fi))
    print("- Precision: {:.4f}".format(model_test_precision))
    print("- Recall: {:.4f}".format(model_test_recall))
    print("- Roc Auc Score: {:.4f}".format(model_test_roc_auc_score))
    
    print("="*35)
    print('\n')
# Out:
# Desision Tree
# Model Performanse for Training
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.9254
# - F1 Score: 0.9250
# - Precision: 0.8172
# - Recall: 0.7958
# - Roc Auc Score: 0.8763
# ===================================
#
#
# Random Forest
# Model Performanse for Training
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.9264
# - F1 Score: 0.9204
# - Precision: 0.9685
# - Recall: 0.6440
# - Roc Auc Score: 0.8194
# ===================================
#
#
# AdaBoost
# Model Performanse for Training
# - Accuracy: 0.8478
# - F1 Score: 0.8146
# - Precision: 0.7815
# - Recall: 0.2551
# - Roc Auc Score: 0.6194
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.8354
# - F1 Score: 0.7987
# - Precision: 0.7500
# - Recall: 0.2356
# - Roc Auc Score: 0.6083
# ===================================
#
#
# GradientBoost
# Model Performanse for Training
# - Accuracy: 0.8939
# - F1 Score: 0.8819
# - Precision: 0.8756
# - Recall: 0.5021
# - Roc Auc Score: 0.7429
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.8589
# - F1 Score: 0.8398
# - Precision: 0.7732
# - Recall: 0.3927
# - Roc Auc Score: 0.6824
# ===================================

# %%
# Hyperparameter Tuning

rf_parem = {
    "max_depth":[5,8,15,None,10],
    "max_features":[5,7,"auto",8],
    "min_samples_split":[2,8,15,20],
    "n_estimators":[100,200,500,1000]
}

adboost_parem = {
    'n_estimators':[50,60,70,80,90],
    'algorithm':['SAMME','SAMME.R'],
    
}

gradientboost_param = {
    "loss":['log_loss','deviance','exponential'],
    "criterion":['friedman_mse','squared_error','mse'],
    "min_samples_split":[2,8,15,20],
    "n_estimators":[100,200,500,1000],
    "max_depth":[5,8,15,None,10]
}

# %%
# Model list for hyperparameters tuning

randomecv_models = [
    ("RF",RandomForestClassifier(),rf_parem),
    ("AB",AdaBoostClassifier(),adboost_parem),
    ("GB",GradientBoostingClassifier(),gradientboost_param)
]

# %%
randomecv_models
# Out:
# [('RF',
#   RandomForestClassifier(),
#   {'max_depth': [5, 8, 15, None, 10],
#    'max_features': [5, 7, 'auto', 8],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000]}),
#  ('AB',
#   AdaBoostClassifier(),
#   {'n_estimators': [50, 60, 70, 80, 90], 'algorithm': ['SAMME', 'SAMME.R']}),
#  ('GB',
#   GradientBoostingClassifier(),
#   {'loss': ['log_loss', 'deviance', 'exponential'],
#    'criterion': ['friedman_mse', 'squared_error', 'mse'],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000],
#    'max_depth': [5, 8, 15, None, 10]})]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name,model,params in randomecv_models:
    random = RandomizedSearchCV(estimator=model,
                                param_distributions=params,
                                n_iter=100,
                                cv=3,
                                verbose=2,
                                n_jobs=-1)
    random.fit(x_train,y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"--------- Best Params for {model_name} -----------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s[CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
#
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=500; total time=   0.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=500; total time=   0.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=500; total time=   0.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=500; total time=   0.8s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   1.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.5s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   0.9s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   0.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   0.8s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   0.9s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   0.9s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   0.8s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   1.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=8, max_features=7, min_samples_split=8, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=8, n_estimators=200; total time=   0.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=8, n_estimators=200; total time=   0.4s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=500; total time=   1.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=   1.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=   1.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=   1.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=1000; total time=   2.4s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=1000; total time=   2.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...................algorithm=SAMME, n_estimators=50; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=50; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=50; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=60; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=60; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=60; total time=   0.1s
# [CV] END .................algorithm=SAMME.R, n_estimators=50; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=50; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=50; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=60; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=60; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=60; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=70; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=70; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=70; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=80; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=80; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=80; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=90; total time=   0.0s
# [CV] END ...................algorithm=SAMME, n_estimators=70; total time=   0.1s
# [CV] END .................algorithm=SAMME.R, n_estimators=90; total time=   0.0s
# [CV] END .................algorithm=SAMME.R, n_estimators=90; total time=   0.0s
# [CV] END ...................algorithm=SAMME, n_estimators=70; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=70; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=80; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=80; total time=   0.1s
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/mohitrajnayak/Data Sci Work/Data Sci REPO/Machine-Learning/venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV] END ...................algorithm=SAMME, n_estimators=80; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=90; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=90; total time=   0.1s
# [CV] END ...................algorithm=SAMME, n_estimators=90; total time=   0.1s
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END criterion=mse, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=squared_error, loss=deviance, max_depth=10, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=10, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END criterion=squared_error, loss=deviance, max_depth=10, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=200; total time=   3.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=200; total time=   3.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=200; total time=   4.0s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=1000; total time=   4.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=1000; total time=   4.5s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=1000; total time=   4.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=500; total time=   3.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=500; total time=   4.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=500; total time=   4.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=500; total time=   3.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END criterion=mse, loss=deviance, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   1.7s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   1.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END criterion=mse, loss=log_loss, max_depth=8, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=8, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=8, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=500; total time=   3.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   1.7s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   4.6s
# [CV] END criterion=mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   4.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=500; total time=   3.4s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=200; total time=   0.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=200; total time=   0.8s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   1.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   1.7s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   1.6s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=200; total time=   0.8s
# ...
# [CV] END criterion=mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=1000; total time=   4.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=1000; total time=   4.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   4.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   4.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   4.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END criterion=squared_error, loss=deviance, max_depth=None, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=None, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=None, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   1.7s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=15, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   1.6s
# [CV] END criterion=squared_error, loss=deviance, max_depth=15, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=15, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   5.6s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   5.8s
# [CV] END criterion=mse, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=15, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=15, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=15, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   1.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   4.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   4.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   4.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   4.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   4.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   4.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   4.4s
# [CV] END criterion=mse, loss=deviance, max_depth=15, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=15, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=15, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=deviance, max_depth=10, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   4.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   4.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=500; total time=   5.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=500; total time=   5.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=500; total time=   4.7s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=500; total time=   4.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=500; total time=   6.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=200; total time=   1.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=200; total time=   1.5s
# [CV] END criterion=mse, loss=deviance, max_depth=None, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=None, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=None, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   3.8s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=500; total time=   5.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   4.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   4.1s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=squared_error, loss=deviance, max_depth=8, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=deviance, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=200; total time=   1.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=500; total time=   4.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=500; total time=   4.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=500; total time=   4.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=100; total time=   1.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=100; total time=   1.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=100; total time=   1.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   4.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   4.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=500; total time=   3.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   4.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=500; total time=   3.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=500; total time=   3.7s
# --------- Best Params for RF -----------
# {'n_estimators': 1000, 'min_samples_split': 2, 'max_features': 8, 'max_depth': None}
# --------- Best Params for AB -----------
# {'n_estimators': 80, 'algorithm': 'SAMME'}
# --------- Best Params for GB -----------
# {'n_estimators': 1000, 'min_samples_split': 15, 'max_depth': 15, 'loss': 'exponential', 'criterion': 'friedman_mse'}

# %%
models = {
    
    "Random Forest":RandomForestClassifier(n_estimators=1000,min_samples_split=2,max_features=7,max_depth=None),
    "Adaboost":AdaBoostClassifier(n_estimators=80,algorithm='SAMME'),
    # "Gradientboost":GradientBoostingClassifier(loss='exponential',criterion='friedman_mse',min_samples_split=8,n_estimators=500,max_depth=10),
    "Gradientboost":GradientBoostingClassifier(loss='exponential',criterion='friedman_mse',min_samples_split=15,n_estimators=1000,max_depth=15)
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train,y_train) # Train Model
    
    # make Predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    # Training set Performanest
    model_train_accuracy = accuracy_score(y_train,y_train_pred)
    model_train_fi = f1_score(y_train,y_train_pred,average='weighted')
    model_train_precision = precision_score(y_train,y_train_pred)
    model_train_recall = recall_score(y_train,y_train_pred)
    model_train_roc_auc_score = roc_auc_score(y_train,y_train_pred)
    
    # Test set Performance
    model_test_accuracy = accuracy_score(y_test,y_test_pred)
    model_test_fi = f1_score(y_test,y_test_pred,average='weighted')
    model_test_precision = precision_score(y_test,y_test_pred)
    model_test_recall = recall_score(y_test,y_test_pred)
    model_test_roc_auc_score = roc_auc_score(y_test,y_test_pred)
    
    print(list(models.keys())[i])
    
    print('Model Performanse for Training')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print("- F1 Score: {:.4f}".format(model_train_fi))
    print("- Precision: {:.4f}".format(model_train_precision))
    print("- Recall: {:.4f}".format(model_train_recall))
    print("- Roc Auc Score: {:.4f}".format(model_train_roc_auc_score))
    
    print('-------------------------------------------')
    
    print('Model Performanse for Test')
    print("- Accuracy: {:.4f}".format(model_test_accuracy))
    print("- F1 Score: {:.4f}".format(model_test_fi))
    print("- Precision: {:.4f}".format(model_test_precision))
    print("- Recall: {:.4f}".format(model_test_recall))
    print("- Roc Auc Score: {:.4f}".format(model_test_roc_auc_score))
    
    print("="*35)
    print('\n')
# Out:
# Random Forest
# Model Performanse for Training
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.9346
# - F1 Score: 0.9301
# - Precision: 0.9704
# - Recall: 0.6859
# - Roc Auc Score: 0.8404
# ===================================
#
#
# Adaboost
# Model Performanse for Training
# - Accuracy: 0.8465
# - F1 Score: 0.8132
# - Precision: 0.7699
# - Recall: 0.2524
# - Roc Auc Score: 0.6176
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.8364
# - F1 Score: 0.7977
# - Precision: 0.7818
# - Recall: 0.2251
# - Roc Auc Score: 0.6049
# ===================================
#
#
# Gradientboost
# Model Performanse for Training
# - Accuracy: 1.0000
# - F1 Score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# -------------------------------------------
# Model Performanse for Test
# - Accuracy: 0.9642
# - F1 Score: 0.9631
# - Precision: 0.9815
# - Recall: 0.8325
# - Roc Auc Score: 0.9143
# ===================================

# %%
## Plot ROC AUC Curve
from sklearn.metrics import roc_auc_score,roc_curve
plt.figure()

# Add the models to the list that you want to view on the ROC plot
auc_models = [
{
    'label': 'Random Forest Classifier',
    'model': RandomForestClassifier(n_estimators=1000,min_samples_split=2,
                                          max_features=7,max_depth=None),
    'auc':  0.8325
},
{
    'label': 'Ada Boost Classifier',
    'model': AdaBoostClassifier(n_estimators=80,algorithm='SAMME'),
    'auc':  0.6049
},
{
    'label': 'Gradient Boost Classifier',
    'model': GradientBoostingClassifier(loss='exponential',criterion='friedman_mse',min_samples_split=15,n_estimators=1000,max_depth=15),
    'auc':  0.9143
},
    
]
# create loop through all model
for algo in auc_models:
    model = algo['model'] # select the model
    model.fit(x_train, y_train) # train the model
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
# Calculate Area under the curve to display on the plot
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (algo['label'], algo['auc']))
# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
# plt.savefig("auc.png")
plt.show()
